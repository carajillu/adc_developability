# %%
import pandas as pd
import seaborn as sns
import glob
import matplotlib
from matplotlib import pyplot as plt
from redim.pca import PCAresult
from redim.kpca import kPCAresult
from redim.umap import UMAPresult
from redim.tsne import tSNEresult
from redim.plots import annotate_plot

# %%
def assign_max_phase(status:str):
    if "Approved" in status or "Apprpved" in status:
        return "Approved"
    elif "Phase 3" in status or "New Drug Application" in status:
        return "Phase 3"
    elif "Phase 2" in status:
        return "Phase 2"
    elif "Phase 1" in status:
        return "Phase 1"
    elif ("Investigative" in status) or ("Investigational" in status):
        return "Investigative"
    elif "inhouse" in status.lower():
        return "Inhouse"
    else:
        print(f"Unknown phase: {status}")
        return "Unknown"

MAX_PHASE_COLORS = {
    "Approved": "#2ca02c",
    "Phase 3": "#1f77b4",
    "Phase 2": "#ff7f0e",
    "Phase 1": "#d62728",
    "Investigative": "#9467bd",
    "Unknown": "#7f7f7f",
    "Inhouse": "#8c564b"
}

def assign_approved(status:str):
    if "Approved" in status or "Apprpved" in status:
        return "Approved"
    elif "inhouse" in status.lower():
        return "Inhouse"
    else:
        return "Not Approved (yet?)"

APPROVED_COLORS = {
    "Approved": "#2ca02c",
    "Not Approved (yet?)": "#d62728",
    "Inhouse": "#8c564b"
}

def assign_withdrawn(status:str):
    status=status.lower()
    if "withdrawn" in status or "discontinued" in status:
        return "Withdrawn"
    elif "inhouse" in status.lower():
          return "Inhouse"
    else:
        return "Not Withdrawn"
WITHDRAWN_COLORS = {
    "Withdrawn": "#d62728", 
    "Not Withdrawn": "#1f77b4",
    "Inhouse": "#8c564b"
}

PALETTE=MAX_PHASE_COLORS
HUE="max_phase"

# %%
#LOAD ADCdb DATASETS
filenames=glob.glob(".data/training/*.csv")
for i in range(len(filenames)):
    print(i, filenames[i])
file_path=filenames[8]
df=pd.read_csv(file_path)
print(df.shape)
df.insert(13,"max_phase",df.adc_status.apply(assign_max_phase))
df.insert(14,"approved",df.adc_status.apply(assign_approved))
df.insert(15,"withdrawn",df.adc_status.apply(assign_withdrawn))
print(df.columns[0:15])
DF_KEYS=["adc_meanDAR"]+df.columns[16:].tolist()
print(DF_KEYS)
print(df.adc_status.value_counts())
# Out:
# 0 .data/esm2_smiles-bert.csv
# 1 .data/developability_TAP_RDkit.csv
# 2 .data/protbert_bert-base-smiles.csv
# 3 .data/esm2_chemberta.csv
# 4 .data/esm2_bert-base-smiles.csv
# 5 .data/distillprotbert_smiles-bert.csv
# 6 .data/protbert_smiles-bert.csv
# 7 .data/quality_light.csv
# 8 .data/distillprotbert_bert-base-smiles.csv
# 9 .data/ADCdb_processed.csv
# 10 .data/protbert_chemberta.csv
# 11 .data/distillprotbert_chemberta.csv
# 12 .data/quality_heavy.csv
# (1001, 3853)
# Unknown phase: Clinical candidate
# Unknown phase: Clinical candidate
# Unknown phase: Terminated
# Index(['adc_id', 'adc_status', 'antibody_HC', 'antibody_LC', 'linker_smiles',
#        'payload_smiles', 'adc_wlpsmiles', 'adc_meanDAR',
#        'antibody_HC_constant', 'antibody_HC_variable', 'antibody_LC_constant',
#        'antibody_LC_variable', 'wlp_token_count', 'max_phase', 'approved'],
#       dtype='object')
# ['adc_meanDAR', 'constant_hc_0', 'constant_hc_1', 'constant_hc_2', 'constant_hc_3', 'constant_hc_4', 'constant_hc_5', 'constant_hc_6', 'constant_hc_7', 'constant_hc_8', 'constant_hc_9', 'constant_hc_10', 'constant_hc_11', 'constant_hc_12', 'constant_hc_13', 'constant_hc_14', 'constant_hc_15', 'constant_hc_16', 'constant_hc_17', 'constant_hc_18', 'constant_hc_19', 'constant_hc_20', 'constant_hc_21', 'constant_hc_22', 'constant_hc_23', 'constant_hc_24', 'constant_hc_25', 'constant_hc_26', 'constant_hc_27', 'constant_hc_28', 'constant_hc_29', 'constant_hc_30', 'constant_hc_31', 'constant_hc_32', 'constant_hc_33', 'constant_hc_34', 'constant_hc_35', 'constant_hc_36', 'constant_hc_37', 'constant_hc_38', 'constant_hc_39', 'constant_hc_40', 'constant_hc_41', 'constant_hc_42', 'constant_hc_43', 'constant_hc_44', 'constant_hc_45', 'constant_hc_46', 'constant_hc_47', 'constant_hc_48', 'constant_hc_49', 'constant_hc_50', 'constant_hc_51', 'constant_hc_52', 'constant_hc_53', 'constant_hc_54', 'constant_hc_55', 'constant_hc_56', 'constant_hc_57', 'constant_hc_58', 'constant_hc_59', 'constant_hc_60', 'constant_hc_61', 'constant_hc_62', 'constant_hc_63', 'constant_hc_64', 'constant_hc_65', 'constant_hc_66', 'constant_hc_67', 'constant_hc_68', 'constant_hc_69', 'constant_hc_70', 'constant_hc_71', 'constant_hc_72', 'constant_hc_73', 'constant_hc_74', 'constant_hc_75', 'constant_hc_76', 'constant_hc_77', 'constant_hc_78', 'constant_hc_79', 'constant_hc_80', 'constant_hc_81', 'constant_hc_82', 'constant_hc_83', 'constant_hc_84', 'constant_hc_85', 'constant_hc_86', 'constant_hc_87', 'constant_hc_88', 'constant_hc_89', 'constant_hc_90', 'constant_hc_91', 'constant_hc_92', 'constant_hc_93', 'constant_hc_94', 'constant_hc_95', 'constant_hc_96', 'constant_hc_97', 'constant_hc_98', 'constant_hc_99', 'constant_hc_100', 'constant_hc_101', 'constant_hc_102', 'constant_hc_103', 'constant_hc_104', 'constant_hc_105', 'constant_hc_106', 'constant_hc_107', 'constant_hc_108', 'constant_hc_109', 'constant_hc_110', 'constant_hc_111', 'constant_hc_112', 'constant_hc_113', 'constant_hc_114', 'constant_hc_115', 'constant_hc_116', 'constant_hc_117', 'constant_hc_118', 'constant_hc_119', 'constant_hc_120', 'constant_hc_121', 'constant_hc_122', 'constant_hc_123', 'constant_hc_124', 'constant_hc_125', 'constant_hc_126', 'constant_hc_127', 'constant_hc_128', 'constant_hc_129', 'constant_hc_130', 'constant_hc_131', 'constant_hc_132', 'constant_hc_133', 'constant_hc_134', 'constant_hc_135', 'constant_hc_136', 'constant_hc_137', 'constant_hc_138', 'constant_hc_139', 'constant_hc_140', 'constant_hc_141', 'constant_hc_142', 'constant_hc_143', 'constant_hc_144', 'constant_hc_145', 'constant_hc_146', 'constant_hc_147', 'constant_hc_148', 'constant_hc_149', 'constant_hc_150', 'constant_hc_151', 'constant_hc_152', 'constant_hc_153', 'constant_hc_154', 'constant_hc_155', 'constant_hc_156', 'constant_hc_157', 'constant_hc_158', 'constant_hc_159', 'constant_hc_160', 'constant_hc_161', 'constant_hc_162', 'constant_hc_163', 'constant_hc_164', 'constant_hc_165', 'constant_hc_166', 'constant_hc_167', 'constant_hc_168', 'constant_hc_169', 'constant_hc_170', 'constant_hc_171', 'constant_hc_172', 'constant_hc_173', 'constant_hc_174', 'constant_hc_175', 'constant_hc_176', 'constant_hc_177', 'constant_hc_178', 'constant_hc_179', 'constant_hc_180', 'constant_hc_181', 'constant_hc_182', 'constant_hc_183', 'constant_hc_184', 'constant_hc_185', 'constant_hc_186', 'constant_hc_187', 'constant_hc_188', 'constant_hc_189', 'constant_hc_190', 'constant_hc_191', 'constant_hc_192', 'constant_hc_193', 'constant_hc_194', 'constant_hc_195', 'constant_hc_196', 'constant_hc_197', 'constant_hc_198', 'constant_hc_199', 'constant_hc_200', 'constant_hc_201', 'constant_hc_202', 'constant_hc_203', 'constant_hc_204', 'constant_hc_205', 'constant_hc_206', 'constant_hc_207', 'constant_hc_208', 'constant_hc_209', 'constant_hc_210', 'constant_hc_211', 'constant_hc_212', 'constant_hc_213', 'constant_hc_214', 'constant ...
# adc_status
# Investigative                                                   935
# Investigational New Drug(IND)                                    13
# Phase 1                                                          10
# Phase 2 (discontinued)                                            8
# Phase 3                                                           6
# Phase 1 (discontinued)                                            6
# Phase 2/3                                                         3
# Clinical candidate                                                2
# Phase 2                                                           2
# Phase 1/2 (discontinued)                                          2
# Phase 1/2                                                         2
# Phase 3 (discontinued)                                            2
# New Drug Application                                              2
# Approved in 2022                                                  1
# Approved in 2013                                                  1
# Phase 3 (terminated/withdrawn)                                    1
# New Drug Application (discontinued)                               1
# Approved in 2025                                                  1
# Approved in 2020 (withdrawn in 2022, approved again in 2025)      1
# Terminated                                                        1
# Approved in 2019                                                  1
# Name: count, dtype: int64

# %%
# Load inhouse Dataset
filenames=glob.glob(".data/test/*.csv")
file_path=filenames[8]
df_test=pd.read_csv(file_path)
df_test.insert(10,"max_phase",df_test.adc_status.apply(assign_max_phase))
df_test.insert(11,"approved",df_test.adc_status.apply(assign_approved))
df_test.insert(12,"withdrawn",df_test.adc_status.apply(assign_withdrawn))
print(df_test.columns[14])
# Out:
# constant_hc_0

# %%
pca = PCAresult(df, feature_keys=DF_KEYS)
df_pca=pd.concat([df, pca.components_df], axis=1)
#pca.plot_pca_loadings()
print(pca.explained_variance_df)
plots,ax=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
sns.scatterplot(data=df_pca, x="PC0", y="PC1",palette=PALETTE,hue=HUE, s=100,alpha=0.5,legend=False,ax=ax[0])
sns.scatterplot(data=df_pca[df_pca.max_phase!="Investigative"], x="PC0", y="PC1",palette=PALETTE,hue=HUE, s=100,alpha=0.5,legend=True,ax=ax[1])
plots.suptitle(f"PCA\n{file_path}")
#ax[0].set_ylim(-10,100)
#annotate_plot(df=df_pca,ax=ax[0],key="adc_id",x="PC0",y="PC1")

plt.show()
# Out:
#              VarPerc  cumVarPerc
# PC0     2.009749e+01   20.097488
# PC1     1.960410e+01   39.701591
# PC2     7.910326e+00   47.611918
# PC3     6.054094e+00   53.666011
# PC4     5.742404e+00   59.408415
# ...              ...         ...
# PC996   1.186950e-31  100.000000
# PC997   1.186950e-31  100.000000
# PC998   5.409008e-32  100.000000
# PC999   4.511501e-32  100.000000
# PC1000  6.028196e-33  100.000000
#
# [1001 rows x 2 columns]

# %%
#??kPCAresult
gamma=0.001
kpca = kPCAresult(df, feature_keys=DF_KEYS, kernel="rbf", gamma=gamma)
df_kpca=pd.concat([df, kpca.components_df], axis=1)
plots,ax=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
sns.scatterplot(data=df_kpca[df_kpca.max_phase=="Investigative"], x="PC0", y="PC1",palette=PALETTE,hue=HUE, s=100,alpha=0.3,legend=False,ax=ax[0])
sns.scatterplot(data=df_kpca[df_kpca.max_phase!="Investigative"], x="PC0", y="PC1",palette=PALETTE,hue=HUE, s=100,alpha=1.0,legend=False,ax=ax[0])
sns.scatterplot(data=df_kpca[df_kpca.max_phase!="Investigative"], x="PC0", y="PC1",palette=PALETTE,hue=HUE, s=100,alpha=0.5,legend=True,ax=ax[1])
plots.suptitle(f"kPCA with RBF kernel, gamma={gamma}\n{file_path}")
plt.show()

# %%
??tSNEresult
perplexity=50
tsne = tSNEresult(df, feature_keys=DF_KEYS, n_components=2, perplexity=perplexity, use_pca=False, pca_components=10, random_state=42)
df_tsne=pd.concat([df, tsne.components_df], axis=1)
plots,ax=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
sns.scatterplot(data=df_tsne[df_tsne.max_phase=="Investigative"], x="tSNE0", y="tSNE1",palette=PALETTE,hue=HUE, s=50,alpha=0.3,legend=False,ax=ax[0])
sns.scatterplot(data=df_tsne[df_tsne.max_phase!="Investigative"], x="tSNE0", y="tSNE1",palette=PALETTE,hue=HUE, s=50,alpha=1.0,legend=False,ax=ax[0])
sns.scatterplot(data=df_tsne[df_tsne.max_phase!="Investigative"], x="tSNE0", y="tSNE1",palette=PALETTE,hue=HUE, s=50,alpha=0.5,legend=True,ax=ax[1])
plots.suptitle(f"tSNE with perplexity={perplexity}\n{file_path}")
plt.show()
# Out:
# Init signature:
# tSNEresult(
#     df: pandas.core.frame.DataFrame,
#     feature_keys: list[str],
#     n_components: int = 2,
#     use_pca: bool = False,
#     pca_components: int = 50,
#     perplexity: float = 30.0,
#     random_state: int = 42,
# ) -> None
# Source:
# class tSNEresult:
#     """
#     Container object for t-SNE results and associated plotting/projection methods.
#     Optionally uses PCA for dimensionality reduction before applying t-SNE.
#     """
#     def __init__(self, df: pd.DataFrame, feature_keys: list[str],
#                  n_components: int = 2, use_pca: bool = False,
#                  pca_components: int = 50, perplexity: float = 30.0,
#                  random_state: int = 42) -> None:
#         """
#         Constructor.
#         Initialises the class and:
#         - checks that feature_keys is a subset of df.columns (throws ValueError if not)
#         - checks that df[feature_keys] does not contain NaN (throws ValueError if it does)
#
#         Input:
#               df: pd.DataFrame with relevant data
#               feature_keys: list[str] with the keys to apply t-SNE on
#               n_components: int, number of dimensions for t-SNE output (default 2)
#               use_pca: bool, whether to use PCA for preprocessing (default False)
#               pca_components: int, number of PCA components if use_pca=True (default 50)
#               perplexity: float, t-SNE perplexity parameter (default 30.0)
#               random_state: int, random state for reproducibility (default 42)
#         Output:
#               None
#         """
#         # Validate feature_keys
#         missing = sorted(set(feature_keys) - set(df.columns))
#         if missing:
#             raise ValueError(f"The following required columns are missing from the DataFrame: {missing}")
#
#         # Check for NaN values
#         nan_mask = df[feature_keys].isna().any()
#         columns_with_nan = nan_mask[nan_mask].index.tolist()
#         if columns_with_nan:
#             raise ValueError(f"The following required columns contain NaN values: {columns_with_nan}")
#
#         self.df = df
#         self.feature_keys = feature_keys
#         self.n_components = n_components
#         self.use_pca = use_pca
#         self.pca_components = pca_components
#         self.random_state = random_state
#
#         self.generate_scaler()
#
#         if self.use_pca:
#             self.generate_pca_object()
#             self.get_pca_components()
#             data_for_tsne = self.pca_components_df.values
#         else:
#             self.pca = None
#             scaled_data = self.scaler.fit_transform(self.df[self.feature_keys])
#             data_for_tsne = scaled_data
#
#         self.generate_tsne_object(perplexity)
#         self.get_tsne_components(data_for_tsne)
#
#         return
#
#     def generate_scaler(self) -> None:
#         """Initialize and fit the StandardScaler on the original feature data."""
#         self.scaler = StandardScaler()
#         self.scaler.fit(self.df[self.feature_keys])
#         return
#
#     def generate_pca_object(self) -> None:
#         """Generate PCA object with specified number of components."""
#         n_pca_components = min([self.pca_components, len(self.feature_keys), len(self.df)])
#         self.pca = PCA(n_components=n_pca_components)
#         return
#
#     def get_pca_components(self) -> None:
#         """Apply PCA to scaled data."""
#         scaled_data = self.scaler.transform(self.df[self.feature_keys])
#         pca_components = self.pca.fit_transform(scaled_data)
#         self.pca_components_df = pd.DataFrame(
#             pca_components,
#             columns=[f"PC{i}" for i in range(self.pca.n_components_)]
#         )
#         return
#
#     def generate_tsne_object(self, perplexity: float) -> None:
#         """Generate t-SNE object with specified parameters."""
#         self.tsne = TSNE(
#             n_components=self.n_components,
#             perplexity=perplexity,
#             random_state=self.random_state,
#             max_iter=1000
#         )
#         return
#
#     def get_tsne_components(self, data: np.ndarray) -> None:
#         """Apply t-SNE to the (possibly PCA-reduced) data."""
#         tsne_components = self.tsne.fit_transform(data)
#         self.components_df = pd.DataFrame(
#             tsne_components,
#             columns=[f"tSNE{i}" for i in range(self.n_components)],
#             index=self.df.index
#         )
#         return
#
#     def project_dataframe(self, z: pd.DataFrame) -> ValueError:
#         raise ValueError("tSNE can't project a new data set onto the training space. PLease append the test set to the training set and refit.")
# File:           ~/github/redim/redim/tsne.py
# Type:           type
# Subclasses:

# %%
??UMAPresult
n_neighbors=15
min_dist=0.5
umap = UMAPresult(df, feature_keys=DF_KEYS, n_components=2, random_state=42,n_neighbors=n_neighbors, min_dist=min_dist)
df_umap=pd.concat([df, umap.components_df], axis=1)
plots,ax=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
sns.scatterplot(data=df_umap[df_umap.max_phase=="Investigative"], x="UMAP0", y="UMAP1",palette=PALETTE,hue=HUE, s=50,alpha=0.3,legend=False,ax=ax[0])
sns.scatterplot(data=df_umap[df_umap.max_phase!="Investigative"], x="UMAP0", y="UMAP1",palette=PALETTE,hue=HUE, s=50,alpha=1.0,legend=False,ax=ax[0])
sns.scatterplot(data=df_umap[df_umap.max_phase!="Investigative"], x="UMAP0", y="UMAP1",palette=PALETTE,hue=HUE, s=50,alpha=0.5,legend=True,ax=ax[1])
plots.suptitle(f"UMAP with n_neighbors={n_neighbors}, min_dist={min_dist}\n{file_path}")
plt.show()
# Out:
# /Users/jclarknicholas/github/adc_developability/.conda/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Init signature:
# UMAPresult(
#     df: pandas.core.frame.DataFrame,
#     feature_keys: list[str],
#     n_components: int = 2,
#     use_pca: bool = False,
#     pca_components: int = 50,
#     n_neighbors: int = 15,
#     min_dist: float = 0.1,
#     random_state: int = 42,
# ) -> None
# Source:
# class UMAPresult:
#     """
#     Container object for UMAP results and associated plotting/projection methods.
#     Optionally uses PCA for dimensionality reduction before applying UMAP.
#     """
#     def __init__(self, df: pd.DataFrame, feature_keys: list[str],
#                  n_components: int = 2, use_pca: bool = False,
#                  pca_components: int = 50, n_neighbors: int = 15,
#                  min_dist: float = 0.1, random_state: int = 42) -> None:
#         """
#         Constructor.
#         Initialises the class and:
#         - checks that feature_keys is a subset of df.columns (throws ValueError if not)
#         - checks that df[feature_keys] does not contain NaN (throws ValueError if it does)
#
#         Input:
#               df: pd.DataFrame with relevant data
#               feature_keys: list[str] with the keys to apply UMAP on
#               n_components: int, number of dimensions for UMAP output (default 2)
#               use_pca: bool, whether to use PCA for preprocessing (default False)
#               pca_components: int, number of PCA components if use_pca=True (default 50)
#               n_neighbors: int, UMAP n_neighbors parameter (default 15)
#               min_dist: float, UMAP min_dist parameter (default 0.1)
#               random_state: int, random state for reproducibility (default 42)
#         Output:
#               None
#         """
#         if umap is None:
#             raise ImportError("UMAP is not installed. Install it with: pip install umap-learn")
#
#         # Validate feature_keys
#         missing = sorted(set(feature_keys) - set(df.columns))
#         if missing:
#             raise ValueError(f"The following required columns are missing from the DataFrame: {missing}")
#
#         # Check for NaN values
#         nan_mask = df[feature_keys].isna().any()
#         columns_with_nan = nan_mask[nan_mask].index.tolist()
#         if columns_with_nan:
#             raise ValueError(f"The following required columns contain NaN values: {columns_with_nan}")
#
#         self.df = df
#         self.feature_keys = feature_keys
#         self.n_components = n_components
#         self.use_pca = use_pca
#         self.pca_components = pca_components
#         self.random_state = random_state
#
#         self.generate_scaler()
#
#         if self.use_pca:
#             self.generate_pca_object()
#             self.get_pca_components()
#             data_for_umap = self.pca_components_df.values
#         else:
#             self.pca = None
#             scaled_data = self.scaler.fit_transform(self.df[self.feature_keys])
#             data_for_umap = scaled_data
#
#         self.generate_umap_object(n_neighbors, min_dist)
#         self.get_umap_components(data_for_umap)
#
#         return
#
#     def generate_scaler(self) -> None:
#         """Initialize and fit the StandardScaler on the original feature data."""
#         self.scaler = StandardScaler()
#         self.scaler.fit(self.df[self.feature_keys])
#         return
#
#     def generate_pca_object(self) -> None:
#         """Generate PCA object with specified number of components."""
#         n_pca_components = min([self.pca_components, len(self.feature_keys), len(self.df)])
#         self.pca = PCA(n_components=n_pca_components)
#         return
#
#     def get_pca_components(self) -> None:
#         """Apply PCA to scaled data."""
#         scaled_data = self.scaler.transform(self.df[self.feature_keys])
#         pca_components = self.pca.fit_transform(scaled_data)
#         self.pca_components_df = pd.DataFrame(
#             pca_components,
#             columns=[f"PC{i}" for i in range(self.pca.n_components_)]
#         )
#         return
#
#     def generate_umap_object(self, n_neighbors: int, min_dist: float) -> None:
#         """Generate UMAP object with specified parameters."""
#         self.umap = umap.UMAP(
#             n_components=self.n_components,
#             n_neighbors=n_neighbors,
#             min_dist=min_dist,
#             random_state=self.random_state
#         )
#         return
#
#     def get_umap_components(self, data: np.ndarray) -> None:
#         """Apply UMAP to the (possibly PCA-reduced) data."""
#         umap_components = self.umap.fit_transform(data)
#         self.components_df = pd.DataFrame(
#             umap_components,
#             columns=[f"UMAP{i}" for i in range(self.n_components)],
#             index=self.df.index
#         )
#         return
#
#     def project_dataframe(self, z: pd.DataFrame) -> pd.DataFrame:
#         """
#         Project new data onto the UMAP space.
#
#         Input:
#               z: pd.DataFrame with the same features as the training data
#         Output:
#               pd.DataFrame with UMAP coordinates for the new data
#         """
#         # Check for missing features
#         missing = set(self.feature_keys) - set(z.columns)
#         if missing:
#             raise KeyError(f"Missing required features in z: {sorted(missing)}")
#
#         z_features = z[self.feature_keys]
#
#         if self.use_pca:
#             # Project through PCA first, then through UMAP
#             z_scaled = self.scaler.transform(z_features)
#             z_pca = self.pca.transform(z_scaled)
#             umap_projection = self.umap.transform(z_pca)
#         else:
#             # Scale and project through UMAP directly
#             z_scaled = self.scaler.transform(z_features)
#             umap_projection = self.umap.transform(z_scaled)
#
#         return pd.DataFrame(
#             umap_projection,
#             index=z.index,
#             columns=self.components_df.columns
#         )
# File:           ~/github/redim/redim/umap.py
# Type:           type
# Subclasses:
